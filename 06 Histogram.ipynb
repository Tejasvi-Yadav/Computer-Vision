# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\PGDUASP\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
x = np.array([78,67,72,57,89,76,86,64,77,78,88,92,87,56,66,67,87,68,91,78])

# %%
plt.xlim(0,100)
plt.xticks(range(0,101,10))
plt.xlabel('Rnage of Marks')
plt.ylabel("Frequency")
plt.hist(x,bins=range(0,101,10));

# %%
sns.histplot(x,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
img = cv2.imread('lenna.png')

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
gray.shape
# Out:
# (512, 512)

# %%
#image,channels,mask,histSize,ranges[.hist[,accumulate]]
hist = cv2.calcHist([gray],[0],None,[256],[0,256])

# %%
len(hist)
# Out:
# 256

# %%
hist[150]
# Out:
# array([2282.], dtype=float32)

# %%
plt.figure()
plt.title('Image Histogram')
plt.xlabel('Pixel Intensity')
plt.ylabel('No of Pixel')          
plt.plot(hist)
plt.xlim([0,256])  #Ensure correct X-axis range
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.title('Image Histogram')
plt.xlabel('Pixel Intensity')
plt.ylabel('No of Pixel') 
plt.xticks(range(0,256,10))
plt.bar(list(range(0,256)),hist.flatten())
#plt.xlim([0,256])  #Ensure correct X-axis range
plt.show()

# %%
plt.hist(gray.flatten(),bins =range(0,256));

# %%
plt.figure(figsize=(16,9))
plt.title('Image Histogram')
plt.xlabel('Pixel Intensity')
plt.ylabel('No of Pixel') 
plt.xticks(range(0,256,10))
plt.hist(gray.flatten(),bins=range(0,256))
#plt.xlim([0,256])  #Ensure correct X-axis range
plt.show()

# %%
gray.mean()
# Out:
# 124.0485610961914

# %%
gray.std()
# Out:
# 47.855599631086996

# %%
gray.min()
# Out:
# 25

# %%
gray.max()
# Out:
# 245

# %% [markdown]
# ### histograms for colors

# %%
b , g, r = cv2.split(img)

# %%
plt.figure(figsize=(16,9))
plt.subplot(1,3,1)
plt.hist(b.flatten(),bins=range(0,256),color = 'b');
plt.subplot(1,3,2)
plt.hist(g.flatten(),bins=range(0,256),color = 'g');
plt.subplot(1,3,3)
plt.hist(r.flatten(),bins=range(0,256),color = 'r');

# %%
plt.figure(figsize=(16,9))
plt.hist(b.flatten(),bins=range(0,256),color = 'b');
plt.hist(g.flatten(),bins=range(0,256),color = 'g');
plt.hist(r.flatten(),bins=range(0,256),color = 'r');

# %% [markdown]
# ### streching and shrinking

# %%
from PIL import Image
# open the image
image = Image.open('lenna.png')

#Define new width and height (larger than original)
new_width,new_height = 512,600

#stretch the image
stretched_image = image.resize((new_width,new_height))

#save the streched image
stretched_image.save('stretched_image.jpg')

stretched_image
# Out:
# <PIL.Image.Image image mode=RGB size=512x600>

# %%
from PIL import Image
# open the image
image = Image.open('lenna.png')

#Define new width and height (larger than original)
new_width,new_height = 512,200

#stretch the image
stretched_image = image.resize((new_width,new_height))

#save the streched image
stretched_image.save('stretched_image.jpg')

stretched_image
# Out:
# <PIL.Image.Image image mode=RGB size=512x200>

# %%
 import cv2
# open the image
image = cv2.imread('lenna.png')

#Define new width and height (larger than original)
new_width,new_height = 512,600

#stretch the image
stretched_image = cv2.resize(image,dsize=(new_width,new_height),interpolation=cv2.INTER_CUBIC)

cv2.imshow('stretched_image',stretched_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
 import cv2
# open the image
image = cv2.imread('lenna.png')

#Define new width and height (larger than original)
new_width,new_height = 1700,1000

#stretch the image
stretched_image = cv2.resize(image,dsize=(new_width,new_height),interpolation=cv2.INTER_CUBIC)

cv2.imshow('stretched_image',stretched_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### histogram equilization

# %%
import numpy as np

img = cv2.imread('lenna.png',0)

#creating a histogram equilization of image using cv2.equalizeHist()
equ = cv2.equalizeHist(img)

#stacking images side by side
res = np.hstack((img,equ))

#show image input vc output
cv2.imshow('image',res)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#stacking images side by side
res = np.vstack((img,equ))

#show image input vc output
cv2.imshow('image',res)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.figure(figsize=(16,9))
plt.subplot(1,2,1)
plt.title("Original Histogram")
plt.xticks(range(0,256,10))
plt.hist(img.flatten(),bins = range(0,256));
plt.subplot(1,2,2)
plt.title("Equalized Histogram")
plt.xticks(range(0,256,10))
plt.hist(equ.flatten(),bins = range(0,256));
